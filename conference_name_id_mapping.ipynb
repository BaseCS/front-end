# %%
import requests

# %%
# %time requests.get('http://localhost:8000/api/v0/conferences').json()
# Out:
# CPU times: user 13.7 ms, sys: 11.6 ms, total: 25.3 ms
# Wall time: 2.23 s
# [{'name': '#MSM', 'id': 6247454},
#  {'name': '#Microposts', 'id': 6247455},
#  {'name': '(KNOW@LOD/CoDeS)@ESWC', 'id': 6247456},
#  {'name': '*SEM', 'id': 6247457},
#  {'name': '*SEM@ACL', 'id': 6247458},
#  {'name': '*SEM@COLING', 'id': 6247459},
#  {'name': '*SEM@NAACL-HLT', 'id': 6247460},
#  {'name': '10th Anniversary Colloquium of UNU/IIST', 'id': 6247461},
#  {'name': '1999 ACM SIGMOD Workshop on Research Issues in Data Mining and Knowledge Discovery',
#   'id': 6247462},
#  {'name': '25 Years Communicating Sequential Processes', 'id': 6247463},
#  {'name': '25 Years ISCA: Retrospectives and Reprints', 'id': 6247464},
#  {'name': '25 Years of Model Checking', 'id': 6247465},
#  {'name': '25th Anniversary of INRIA', 'id': 6247466},
#  {'name': '3D Image Processing, Measurement (3DIPM), and Applications',
#   'id': 6247467},
#  {'name': '3D-GIS', 'id': 6247468},
#  {'name': '3DCVE@VR', 'id': 6247469},
# ...

# %%
len([conference['name'] for conference in requests.get('http://localhost:8000/api/v0/conferences').json()])
# Out:
# 12825

# %%
cs_rankings_conferences = set([
    "AAAI",
    "IJCAI",
    "CVPR",
    "ECCV",
    "ICCV",
    "ICML",
    "KDD",
    "NeurIPS",
    "NIPS",
    "ACL",
    "EMNLP",
    "NAACL",
    "SIGIR",
    "WWW",
    "ASPLOS",
    "ISCA",
    "MICRO",
    "HPCA",
    "SIGCOMM",
    "NSDI",
    "CCS",
    "IEEE Symposium on Security and Privacy",
    "USENIX Security Symposium",
    "NDSS",
    "SIGMOD Conference",
    "VLDB",
    "ICDE",
    "PODS",
    "DAC",
    "ICCAD",
    "EMSOFT",
    "RTAS",
    "RTSS",
    "HPDC",
    "ICS",
    "SC",
    "MobiCom",
    "MobiSys",
    "SenSys",
    "IMC",
    "SIGMETRICS",
    "OSDI",
    "SOSP",
    "EuroSys",
    "FAST",
    "USENIX Annual Technical Conference",
    "PLDI",
    "POPL",
    "ICFP",
    "OOPSLA",
    "FSE",
    "ICSE",
    "ASE",
    "ISSTA",
    "FOCS",
    "SODA",
    "STOC",
    "CRYPTO",
    "EUROCRYPT",
    "CAV",
    "LICS",
    "ISMB",
    "RECOMB",
    "SIGGRAPH",
    "SIGGRAPH Asia",
    "EC",
    "WINE",
    "CHI",
    "UbiComp",
    "Pervasive",
    "IMWUT",
    "UIST",
    "ICRA",
    "IROS",
    "Robotics: Science and Systems",
    "VIS",
    "VR"
])

# %%
cs_rankings_ids = [{'id': conference['id'], 'name': conference['name']} for conference in requests.get('http://localhost:8000/api/v0/conferences').json() if conference['name'] in cs_rankings_conferences]

cs_rankings_ids
# Out:
# [{'id': 6247512, 'name': 'AAAI'},
#  {'id': 6247782, 'name': 'ACL'},
#  {'id': 6252198, 'name': 'ASE'},
#  {'id': 6252225, 'name': 'ASPLOS'},
#  {'id': 6253528, 'name': 'CAV'},
#  {'id': 6253603, 'name': 'CCS'},
#  {'id': 6253698, 'name': 'CHI'},
#  {'id': 6254115, 'name': 'CRYPTO'},
#  {'id': 6254300, 'name': 'CVPR'},
#  {'id': 6255215, 'name': 'DAC'},
#  {'id': 6256358, 'name': 'EC'},
#  {'id': 6256393, 'name': 'ECCV'},
#  {'id': 6256634, 'name': 'EMNLP'},
#  {'id': 6256662, 'name': 'EMSOFT'},
#  {'id': 6256833, 'name': 'EUROCRYPT'},
#  {'id': 6257040, 'name': 'EuroSys'},
#  {'id': 6257154, 'name': 'FAST'},
#  {'id': 6257859, 'name': 'FOCS'},
#  {'id': 6257902, 'name': 'FSE'},
#  {'id': 6259062, 'name': 'HPCA'},
#  {'id': 6259079, 'name': 'HPDC'},
#  {'id': 6260525, 'name': 'ICCAD'},
#  {'id': 6260632, 'name': 'ICCV'},
#  {'id': 6260661, 'name': 'ICDE'},
#  {'id': 6260758, 'name': 'ICFP'},
#  {'id': 6260948, 'name': 'ICML'},
#  {'id': 6261615, 'name': 'ICRA'},
# ...

# %%
cs_rankings_conferences
# Out:
# {'AAAI',
#  'ACL',
#  'ASE',
#  'ASPLOS',
#  'CAV',
#  'CCS',
#  'CHI',
#  'CRYPTO',
#  'CVPR',
#  'DAC',
#  'EC',
#  'ECCV',
#  'EMNLP',
#  'EMSOFT',
#  'EUROCRYPT',
#  'EuroSys',
#  'FAST',
#  'FOCS',
#  'FSE',
#  'HPCA',
#  'HPDC',
#  'ICCAD',
#  'ICCV',
#  'ICDE',
#  'ICFP',
#  'ICML',
#  'ICRA',
#  'ICS',
#  'ICSE',
#  'IEEE Symposium on Security and Privacy',
#  'IJCAI',
#  'IMC',
#  'IMWUT',
#  'IROS',
#  'ISCA',
#  'ISMB',
#  'ISSTA',
#  'KDD',
#  'LICS',
#  'MICRO',
#  'MobiCom',
#  'MobiSys',
#  'NAACL',
#  'NDSS',
#  'NIPS',
#  'NSDI',
#  'NeurIPS',
#  'OOPSLA',
#  'OSDI',
#  'PLDI',
#  'PODS',
#  'POPL',
#  'Pervasive',
#  'RECOMB',
#  'RTAS',
#  'RTSS',
#  'Robotics: Science and Systems',
#  'SC',
#  'SIGCOMM',
#  'SIGGRAPH',
#  'SIGGRAPH Asia',
#  'SIGIR',
#  'SIGMETRICS',
#  'SIGMOD Conference',
#  'SODA',
#  'SOSP',
#  'STOC',
#  'SenSys',
#  'UIST',
#  'USENIX Annual Technical Conference',
#  'USENIX Security Symposium',
#  'UbiComp',
#  'VIS',
#  'VLDB',
#  'VR',
# ...

# %%
cs_rankings_conferences - set([conference['name'] for conference in cs_rankings_ids])
# Out:
# {'IMWUT'}

# %%
[conference['name'] for conference in requests.get('http://localhost:8000/api/v0/conferences').json() if 'Ubiquitous' in conference['name']]
# Out:
# ['Data Always and Everywhere - Management of Mobile, Ubiquitous, Pervasive, and Sensor Data',
#  'Designing Ubiquitous Information Environments',
#  'Mobile HCI Workshop on Mobile and Ubiquitous Information Access',
#  'Programming Models for Ubiquitous Parallelism',
#  'Workshop on Universal Accessibility of Ubiquitous Computing']

# %%
cs_rankings_ids
# Out:
# [{'id': 6247512, 'name': 'AAAI'},
#  {'id': 6247782, 'name': 'ACL'},
#  {'id': 6252198, 'name': 'ASE'},
#  {'id': 6252225, 'name': 'ASPLOS'},
#  {'id': 6253528, 'name': 'CAV'},
#  {'id': 6253603, 'name': 'CCS'},
#  {'id': 6253698, 'name': 'CHI'},
#  {'id': 6254115, 'name': 'CRYPTO'},
#  {'id': 6254300, 'name': 'CVPR'},
#  {'id': 6255215, 'name': 'DAC'},
#  {'id': 6256358, 'name': 'EC'},
#  {'id': 6256393, 'name': 'ECCV'},
#  {'id': 6256634, 'name': 'EMNLP'},
#  {'id': 6256662, 'name': 'EMSOFT'},
#  {'id': 6256833, 'name': 'EUROCRYPT'},
#  {'id': 6257040, 'name': 'EuroSys'},
#  {'id': 6257154, 'name': 'FAST'},
#  {'id': 6257859, 'name': 'FOCS'},
#  {'id': 6257902, 'name': 'FSE'},
#  {'id': 6259062, 'name': 'HPCA'},
#  {'id': 6259079, 'name': 'HPDC'},
#  {'id': 6260525, 'name': 'ICCAD'},
#  {'id': 6260632, 'name': 'ICCV'},
#  {'id': 6260661, 'name': 'ICDE'},
#  {'id': 6260758, 'name': 'ICFP'},
#  {'id': 6260948, 'name': 'ICML'},
#  {'id': 6261615, 'name': 'ICRA'},
# ...
